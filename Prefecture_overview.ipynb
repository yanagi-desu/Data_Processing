# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as stat

# %%
survey_raw = pd.read_csv("Raw_survey_data.csv")
survey_raw["dummy"] = [1]*1600

# %%
prefecture_overview = survey_raw.groupby("Prefecture_code").count()
prefecture_overview = prefecture_overview.rename(columns = {"dummy":"Population"},index = {11:"Saitama",12:"Chiba",13:"Tokyo",14:"Kanagawa"})
prefecture_population_overview = prefecture_overview["Population"]
prefecture_population_overview.plot(kind = "pie")
prefecture_population_overview.
# Out:
# Prefecture_code
# Saitama     400
# Chiba       400
# Tokyo       400
# Kanagawa    400
# Name: Population, dtype: int64

# %%
prefecture_overview = survey_raw.groupby("Prefecture_code").count()
prefecture_overview.head()
prefecture_overview = prefecture_overview["Age_Catagory","Sex"]
# Out:
#      №  Prefecture_code  TypeOfRes  Sex  Age  Age_Catagory  Sex_Era  Married  \
# 0    1               11          3    2   24             2       10        1
# 1    2               12          3    1   32             3        3        2
# 2    3               13          3    1   37             3        3        2
# 3    4               13          3    1   46             4        4        2
# 4    5               12          3    1   22             2        2        1
# 5    6               13          3    1   29             2        2        2
# 6    7               12          3    2   63             6       14        1
# 7    8               13          3    2   38             3       11        2
# 8   10               11          3    1   48             4        4        1
# 9   13               11          3    1   29             2        2        1
# 10  15               11          3    1   46             4        4        2
# ...
